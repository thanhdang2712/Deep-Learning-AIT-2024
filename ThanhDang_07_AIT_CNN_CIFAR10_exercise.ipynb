# %% [markdown]
# # Copyright
#
# <PRE>
# Copyright (c) 2024 Bálint Gyires-Tóth - All Rights Reserved
# You may use and modify this code for research and development purpuses.
# Using this code for educational purposes (self-paced or instructor led) without the permission of the author is prohibited.
# </PRE>

# %% [markdown]
# # Convolutional Neural Network exercise
#
# In this notebook, you will build a convolutional neural network, which offers superior results over the previous MLP solution. Additionally, you will perform a more detailed evaluation.

# %%
# imports
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # 1. Data
# The dataset we will use is the well-known CIFAR10 (Canadian Institute For Advanced Research). Explore the details on the Keras website first: https://keras.io/api/datasets/cifar10/
#
# There isn't much difference between the data preprocessing part and the one we did before. The only difference is that we don't have to reshape images into vectors, but we are working with a 4 dimensional data structure, where the dimensions are: batch, X, Y, and color channels.
#
# In the event that anything is not clear regarding the data preparation part, please check the previous CIFAR10 notebook.

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step

# %%
# it is in int8 format, the neural network requires float32
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %%
train_ratio  = 0.8
train_length = X_train.shape[0]
train_split  = int(train_ratio*train_length)
X_valid, Y_valid = X_train[train_split:], Y_train[train_split:]
X_train, Y_train = X_train[:train_split], Y_train[:train_split]

# %%
mean = X_train.mean(axis=0)
std  = X_train.std(axis=0)

X_train = (X_train-mean)/std
X_valid = (X_valid-mean)/std
X_test  = (X_test-mean)/std

# %%
nb_classes = len(np.unique(Y_train))
Y_train = to_categorical(Y_train, nb_classes)
Y_valid = to_categorical(Y_valid, nb_classes)
Y_test  = to_categorical(Y_test, nb_classes)

# %%
print("Shapes of the training, validation and test input data:", X_train.shape, X_valid.shape, X_test.shape)
print("Shapes of the training, validation and test output data:", Y_train.shape, Y_valid.shape, Y_test.shape)
print("Mean values of the training, validation and test input data:", X_train.mean(), X_valid.mean(), X_test.mean())
print("Standard deviation of the training, validation and test input data:", X_train.std(), X_valid.std(), X_test.std())
# Out:
# Shapes of the training, validation and test input data: (40000, 32, 32, 3) (10000, 32, 32, 3) (10000, 32, 32, 3)
# Shapes of the training, validation and test output data: (40000, 10) (10000, 10) (10000, 10)
# Mean values of the training, validation and test input data: 2.2788842e-09 0.0023437198 0.013331206
# Standard deviation of the training, validation and test input data: 1.0000023 0.9965626 0.99783075

# %% [markdown]
# # 2. Exercise: training

# %% [markdown]
# Create and train a convolutional neural network with the following requirements:
# * apply early stopping with patience=5 and monitor the validation accuracy, don't forget to load back the best weights after early stopping
# * the number of trainable parameters is lower than 200.000
# * the validation accuracy must be higher than 72%
#
# Hints:
# * you can always inspect the number of trainable parameters per layer with model.summary()
# * usually the most trainable parameters are between the last convolutional layer and the next dense layer -- so you should have a reasonable output size at the last convolutional layer
# * regularization helps (e.g. DropOut and/or BatchNormalization)
# * use the right activation function at the output layer and the corresponding loss function
# * for the chosen activation functions, please use the appropriate initialization method
# * you can match the dimension of the last conv/pooling layer to the next dense layer with e.g. Flatten()
# * ADAM optimizer is a reasonable choice
# * don't forget to turn on GPU support in Colab, otherwise, it would be quite slow to train the networks

# %%
es = EarlyStopping(monitor='val_accuracy', patience=5, min_delta=0.005, restore_best_weights=True) # early stopping

# %%
# model definition
model = Sequential([
    Conv2D(75, (3, 3), activation='relu',strides=1, padding="same",kernel_initializer=HeNormal(), input_shape=(32, 32, 3)),
    BatchNormalization(),
    MaxPool2D((2, 2), strides=2, padding="same"),
    Conv2D(50, (3, 3), strides=1, padding="same", activation="relu"),
    Dropout(0.2),
    BatchNormalization(),
    MaxPool2D((2, 2), strides=2, padding="same"),
    Conv2D(25, (3, 3), activation='relu', kernel_initializer=HeNormal(), padding="same"),
    BatchNormalization(),
    MaxPool2D((2, 2), strides=2, padding="same"),
    Dropout(0.3),
    Flatten(),
    Dense(128, activation='relu', kernel_initializer=HeNormal()),
    Dropout(0.4),
    Dense(units=nb_classes, activation='softmax')
])

# loss function and optimizer
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 32, 32, 75)        2100
#
#  batch_normalization_18 (Ba  (None, 32, 32, 75)        300
#  tchNormalization)
#
#  max_pooling2d_17 (MaxPooli  (None, 16, 16, 75)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 50)        33800
#
#  dropout_16 (Dropout)        (None, 16, 16, 50)        0
#
#  batch_normalization_19 (Ba  (None, 16, 16, 50)        200
#  tchNormalization)
#
#  max_pooling2d_18 (MaxPooli  (None, 8, 8, 50)          0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 25)          11275
#
#  batch_normalization_20 (Ba  (None, 8, 8, 25)          100
#  tchNormalization)
#
#  max_pooling2d_19 (MaxPooli  (None, 4, 4, 25)          0
#  ng2D)
#
#  dropout_17 (Dropout)        (None, 4, 4, 25)          0
#
#  flatten_5 (Flatten)         (None, 400)               0
#
#  dense_10 (Dense)            (None, 128)               51328
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 100393 (392.16 KB)
# Trainable params: 100093 (390.99 KB)
# Non-trainable params: 300 (1.17 KB)
# _________________________________________________________________

# %% [markdown]
# Please, check the number of trainable paramers:

# %%
print("#trainable parameters:",model.count_params())
# Out:
# #trainable parameters: 100393

# %%
# training
network_history = model.fit(X_train, Y_train,
                            validation_data=(X_valid,Y_valid),
                            epochs=100,
                            verbose=1)
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 12s 8ms/step - loss: 1.6963 - accuracy: 0.3930 - val_loss: 1.2376 - val_accuracy: 0.5593
# Epoch 2/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.2931 - accuracy: 0.5353 - val_loss: 1.0952 - val_accuracy: 0.6087
# Epoch 3/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.1426 - accuracy: 0.5949 - val_loss: 1.0256 - val_accuracy: 0.6385
# Epoch 4/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 1.0416 - accuracy: 0.6328 - val_loss: 0.9015 - val_accuracy: 0.6802
# Epoch 5/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.9697 - accuracy: 0.6603 - val_loss: 0.8609 - val_accuracy: 0.6973
# Epoch 6/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9241 - accuracy: 0.6764 - val_loss: 0.7978 - val_accuracy: 0.7160
# Epoch 7/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.8784 - accuracy: 0.6887 - val_loss: 0.7921 - val_accuracy: 0.7223
# Epoch 8/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.8480 - accuracy: 0.7039 - val_loss: 0.8034 - val_accuracy: 0.7164
# Epoch 9/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8208 - accuracy: 0.7129 - val_loss: 0.7505 - val_accuracy: 0.7361
# Epoch 10/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.7942 - accuracy: 0.7203 - val_loss: 0.7450 - val_accuracy: 0.7401
# Epoch 11/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.7723 - accuracy: 0.7303 - val_loss: 0.7125 - val_accuracy: 0.7561
# Epoch 12/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.7568 - accuracy: 0.7323 - val_loss: 0.7011 - val_accuracy: 0.7607
# Epoch 13/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7424 - accuracy: 0.7394 - val_loss: 0.6919 - val_accuracy: 0.7586
# Epoch 14/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.7231 - accuracy: 0.7445 - val_loss: 0.6806 - val_accuracy: 0.7644
# Epoch 15/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.7094 - accuracy: 0.7524 - val_loss: 0.6542 - val_accuracy: 0.7748
# Epoch 16/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6944 - accuracy: 0.7573 - val_loss: 0.6614 - val_accuracy: 0.7703
# Epoch 17/100
# 1250/1250 [==============================] - 15s 12ms/step - loss: 0.6875 - accuracy: 0.7599 - val_loss: 0.6738 - val_accuracy: 0.7669
# Epoch 18/100
# 1250/1250 [==============================] - 14s 11ms/step - loss: 0.6690 - accuracy: 0.7649 - val_loss: 0.6730 - val_accuracy: 0.7688
# Epoch 19/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6648 - accuracy: 0.7643 - val_loss: 0.6427 - val_accuracy: 0.7778
# Epoch 20/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6530 - accuracy: 0.7723 - val_loss: 0.6392 - val_accuracy: 0.7827
# Epoch 21/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6443 - accuracy: 0.7754 - val_loss: 0.6431 - val_accuracy: 0.7782
# Epoch 22/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6380 - accuracy: 0.7779 - val_loss: 0.6511 - val_accuracy: 0.7771
# Epoch 23/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6245 - accuracy: 0.7798 - val_loss: 0.6349 - val_accuracy: 0.7802
# Epoch 24/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6196 - accuracy: 0.7812 - val_loss: 0.6286 - val_accuracy: 0.7838
# Epoch 25/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6141 - accuracy: 0.7856 - val_loss: 0.6428 - val_accuracy: 0.7783
# Epoch 26/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.6053 - accuracy: 0.7873 - val_loss: 0.6438 - val_accuracy: 0.7804
# Epoch 27/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5987 - accuracy: 0.7893 - val_loss: 0.6175 - val_accuracy: 0.7860
# Epoch 28/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5938 - accuracy: 0.7924 - val_loss: 0.5933 - val_accuracy: 0.7929
# Epoch 29/100
# 1250/1250 [==============================] - 9s 8ms/step - loss: 0.5854 - accuracy: 0.7946 - val_loss: 0.6184 - val_accuracy: 0.7882
# Epoch 30/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5833 - accuracy: 0.7951 - val_loss: 0.6280 - val_accuracy: 0.7855
# Epoch 31/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5819 - accuracy: 0.7946 - val_loss: 0.6057 - val_accuracy: 0.7929
# Epoch 32/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5737 - accuracy: 0.8014 - val_loss: 0.6000 - val_accuracy: 0.7935
# Epoch 33/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5733 - accuracy: 0.7983 - val_loss: 0.6224 - val_accuracy: 0.7869
# Epoch 34/100
# 1250/1250 [==============================] - 11s 8ms/step - loss: 0.5665 - accuracy: 0.8014 - val_loss: 0.5982 - val_accuracy: 0.7945
# Epoch 35/100
# 1250/1250 [==============================] - 11s 8ms/step - loss: 0.5587 - accuracy: 0.8015 - val_loss: 0.6755 - val_accuracy: 0.7726
# Epoch 36/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5553 - accuracy: 0.8046 - val_loss: 0.5900 - val_accuracy: 0.7971
# Epoch 37/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5457 - accuracy: 0.8117 - val_loss: 0.5792 - val_accuracy: 0.8001
# Epoch 38/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5490 - accuracy: 0.8073 - val_loss: 0.5988 - val_accuracy: 0.7951
# Epoch 39/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5443 - accuracy: 0.8088 - val_loss: 0.6038 - val_accuracy: 0.7965
# Epoch 40/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5449 - accuracy: 0.8097 - val_loss: 0.6211 - val_accuracy: 0.7882
# Epoch 41/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5364 - accuracy: 0.8109 - val_loss: 0.5920 - val_accuracy: 0.8007
# Epoch 42/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5291 - accuracy: 0.8145 - val_loss: 0.5921 - val_accuracy: 0.7971
# Epoch 43/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5253 - accuracy: 0.8178 - val_loss: 0.6022 - val_accuracy: 0.7974
# Epoch 44/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5274 - accuracy: 0.8148 - val_loss: 0.5984 - val_accuracy: 0.7963
# Epoch 45/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5255 - accuracy: 0.8152 - val_loss: 0.5933 - val_accuracy: 0.7946
# Epoch 46/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5214 - accuracy: 0.8161 - val_loss: 0.6142 - val_accuracy: 0.7925
# Epoch 47/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5169 - accuracy: 0.8184 - val_loss: 0.5942 - val_accuracy: 0.8007
# Epoch 48/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.5154 - accuracy: 0.8188 - val_loss: 0.5739 - val_accuracy: 0.8014
# Epoch 49/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5153 - accuracy: 0.8191 - val_loss: 0.5786 - val_accuracy: 0.8046
# Epoch 50/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5101 - accuracy: 0.8186 - val_loss: 0.5871 - val_accuracy: 0.8038
# Epoch 51/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5017 - accuracy: 0.8245 - val_loss: 0.6238 - val_accuracy: 0.7916
# Epoch 52/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4988 - accuracy: 0.8248 - val_loss: 0.6209 - val_accuracy: 0.7945
# Epoch 53/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4989 - accuracy: 0.8260 - val_loss: 0.5870 - val_accuracy: 0.7987
# Epoch 54/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4930 - accuracy: 0.8262 - val_loss: 0.5866 - val_accuracy: 0.8025
# Epoch 55/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4966 - accuracy: 0.8273 - val_loss: 0.5825 - val_accuracy: 0.8065
# Epoch 56/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4938 - accuracy: 0.8245 - val_loss: 0.5904 - val_accuracy: 0.8017
# Epoch 57/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4917 - accuracy: 0.8268 - val_loss: 0.5897 - val_accuracy: 0.8038
# Epoch 58/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4909 - accuracy: 0.8276 - val_loss: 0.5906 - val_accuracy: 0.7994
# Epoch 59/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4836 - accuracy: 0.8304 - val_loss: 0.6188 - val_accuracy: 0.7952
# Epoch 60/100
# 1250/1250 [==============================] - 10s 8ms/step - loss: 0.4854 - accuracy: 0.8294 - val_loss: 0.5907 - val_accuracy: 0.8014
# Epoch 61/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4816 - accuracy: 0.8313 - val_loss: 0.5893 - val_accuracy: 0.8036
# Epoch 62/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4873 - accuracy: 0.8294 - val_loss: 0.5958 - val_accuracy: 0.8009
# Epoch 63/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4742 - accuracy: 0.8328 - val_loss: 0.6351 - val_accuracy: 0.7903
# Epoch 64/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4761 - accuracy: 0.8310 - val_loss: 0.5816 - val_accuracy: 0.8018
# Epoch 65/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4696 - accuracy: 0.8363 - val_loss: 0.5613 - val_accuracy: 0.8095
# Epoch 66/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4658 - accuracy: 0.8360 - val_loss: 0.5821 - val_accuracy: 0.8066
# Epoch 67/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4757 - accuracy: 0.8330 - val_loss: 0.6045 - val_accuracy: 0.8019
# Epoch 68/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4678 - accuracy: 0.8349 - val_loss: 0.5804 - val_accuracy: 0.8070
# Epoch 69/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4704 - accuracy: 0.8346 - val_loss: 0.6212 - val_accuracy: 0.7948
# Epoch 70/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.4637 - accuracy: 0.8374 - val_loss: 0.6008 - val_accuracy: 0.8018
# Epoch 71/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4710 - accuracy: 0.8340 - val_loss: 0.5719 - val_accuracy: 0.8074
# Epoch 72/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4618 - accuracy: 0.8381 - val_loss: 0.5591 - val_accuracy: 0.8154
# Epoch 73/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4631 - accuracy: 0.8372 - val_loss: 0.5726 - val_accuracy: 0.8083
# Epoch 74/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4583 - accuracy: 0.8380 - val_loss: 0.5634 - val_accuracy: 0.8137
# Epoch 75/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4556 - accuracy: 0.8387 - val_loss: 0.5849 - val_accuracy: 0.8053
# Epoch 76/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4540 - accuracy: 0.8411 - val_loss: 0.5914 - val_accuracy: 0.8066
# Epoch 77/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4529 - accuracy: 0.8388 - val_loss: 0.5639 - val_accuracy: 0.8150
# Epoch 78/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4506 - accuracy: 0.8403 - val_loss: 0.5724 - val_accuracy: 0.8058
# Epoch 79/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4519 - accuracy: 0.8401 - val_loss: 0.5819 - val_accuracy: 0.8086
# Epoch 80/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4465 - accuracy: 0.8427 - val_loss: 0.5773 - val_accuracy: 0.8064
# Epoch 81/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4475 - accuracy: 0.8407 - val_loss: 0.5777 - val_accuracy: 0.8128
# Epoch 82/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4435 - accuracy: 0.8435 - val_loss: 0.6137 - val_accuracy: 0.7990
# Epoch 83/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4426 - accuracy: 0.8438 - val_loss: 0.5976 - val_accuracy: 0.8083
# Epoch 84/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4455 - accuracy: 0.8439 - val_loss: 0.5691 - val_accuracy: 0.8117
# Epoch 85/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4380 - accuracy: 0.8448 - val_loss: 0.5872 - val_accuracy: 0.8074
# Epoch 86/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4354 - accuracy: 0.8472 - val_loss: 0.6129 - val_accuracy: 0.8036
# Epoch 87/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4425 - accuracy: 0.8446 - val_loss: 0.6056 - val_accuracy: 0.8011
# Epoch 88/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4342 - accuracy: 0.8453 - val_loss: 0.5790 - val_accuracy: 0.8083
# Epoch 89/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4383 - accuracy: 0.8454 - val_loss: 0.5715 - val_accuracy: 0.8116
# Epoch 90/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4359 - accuracy: 0.8461 - val_loss: 0.5750 - val_accuracy: 0.8105
# Epoch 91/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4369 - accuracy: 0.8467 - val_loss: 0.5674 - val_accuracy: 0.8111
# Epoch 92/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4322 - accuracy: 0.8461 - val_loss: 0.5728 - val_accuracy: 0.8141
# Epoch 93/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4272 - accuracy: 0.8475 - val_loss: 0.5672 - val_accuracy: 0.8124
# Epoch 94/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4268 - accuracy: 0.8486 - val_loss: 0.5733 - val_accuracy: 0.8114
# Epoch 95/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4294 - accuracy: 0.8492 - val_loss: 0.5671 - val_accuracy: 0.8158
# Epoch 96/100
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4279 - accuracy: 0.8478 - val_loss: 0.5742 - val_accuracy: 0.8056
# Epoch 97/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4218 - accuracy: 0.8492 - val_loss: 0.5821 - val_accuracy: 0.8114
# Epoch 98/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4265 - accuracy: 0.8493 - val_loss: 0.6089 - val_accuracy: 0.8049
# Epoch 99/100
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.4329 - accuracy: 0.8469 - val_loss: 0.5796 - val_accuracy: 0.8101
# Epoch 100/100
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4248 - accuracy: 0.8498 - val_loss: 0.5810 - val_accuracy: 0.8097

# %% [markdown]
# # 3. Exercise: evaluation on test data
# You will evaluate the classification of the test data using the common metrics and the confusion matrix in this section.
#
#
# As a first stes, let's run the predictions and convert the predicted softmax outputs to dense labels. The one-hot encoded labels are also converted back to dense labels, as they are required for the evaluation functions.

# %%
probas = model.predict(X_test)
preds  = np.argmax(probas,axis=1)
Y_test_dense = np.argmax(Y_test, axis=1) # get the original dense labels of the test data
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ## 3.1. Exercise: Metrics
# please review the common classification metrics (accuracy, precision, recall, F1) for the complete model (not per class).
#
# Hints:
# * use macro averaging
# * you have to import the right functions from [sklearn.metrics](https://scikit-learn.org/stable/modules/model_evaluation.html)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Calculate metrics
accuracy = accuracy_score(Y_test_dense, preds)
precision = precision_score(Y_test_dense, preds, average='macro')
recall = recall_score(Y_test_dense, preds, average='macro')
f1 = f1_score(Y_test_dense, preds, average='macro')

# Print metrics
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.8075
# Precision: 0.810464505106103
# Recall: 0.8074999999999999
# F1 Score: 0.8067936904679183

# %% [markdown]
# ## 3.2. Exercise: Confusion matrix
# Calculate the confusion matrix and display the results in a heatmap (with decimal values).
#
# Hints:
# * you have to do the imports this time too, e.g. from [sklearn.metrics](https://scikit-learn.org/stable/modules/model_evaluation.html) and the [heatmap function](https://seaborn.pydata.org/generated/seaborn.heatmap.html) of [seaborn](https://seaborn.pydata.org/)
# * for displaying the decimal values, you have to turn annot=True and define fmt='d' in the heatmap function of seaborn

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# Calculate confusion matrix
cm = confusion_matrix(Y_test_dense, preds, normalize='true')

# Display as a heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='.2%', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
